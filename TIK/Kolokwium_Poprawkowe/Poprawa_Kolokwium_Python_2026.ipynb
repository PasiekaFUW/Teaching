# %% [markdown]
# # Poprawa sprawdzianu z Pythona
# **Limit czasu: 60 minut | Maksymalna liczba punktów: 15**
#
# Sprawdzian składa się z 3 zadań. Za każde z nich możesz zdobyć maksymalnie 5 punktów. Powodzenia!

# %% [markdown]
# ## Zadanie 1 - Kolekcje Danych i iteratory (5 punktów)
#
# **Wymagania (1 punkt za każdy podpunkt):**
# 1. Stwórz `słownik` zawierający nazwy produktów spożywczych jako klucze oraz ich ceny jako wartości.
# 2. Utwórz pętlę `for`, która przejdzie po wszystkich kluczach w słowniku.
# 3. Umieść te klucze, dla których cena produktu jest wyższa niż 10 w nowej liście o nazwie `drogie`.
# 4. Użyj funkcji `enumerate`, aby wypisać indeksy i nazwy co drugiego elementu z listy `drogie`.

# %%
#Tu umieść swoje rozwiązanie

# %% [markdown]
# ## Zadanie 2 - NumPy (5 punktów)
#
# **Wymagania (1 punkt za każdy podpunkt):**
# 1. Utwórz listę `ndarray` o nazwie `liczby` związaną z pakietem `numpy` z 16 liczbami całkowitymi wpisanymi ręcznie.
# 2. Zmień kształt listy na tablicę 4x4 za pomocą odpowiedniej instrukcji.
# 3. Znajdź wartości własne powstałej macierzy i wypisz pierwszą z nich (odnieś się do odpowiedniego elementu w liście).
# 4. Utwórz funkcję, która przyjmie jako argument liczbę i sprawdzi czy jest parzysta. Jeśli tak, zwróci tę liczbę ze zmienionym znakiem. Jeśli nie zwróci 1.
# 5. Zastosuj napisaną funkcję do pierwotnej listy `liczby`, zamień ją na macierz i znajdź nowe wartości własne.

# %%
#Tu umieść swoje rozwiązanie

# %% [markdown]
# ## Zadanie 3 - Optymalizacja (5 punktów)
#
# **Wymagania (1 punkt za każdy podpunkt):**
# 1. Zdefiniuj funkcję, która zwraca wartość ze wzoru $a \ln( x^2) + bx^3+c$. WSKAZÓWKA: Użyj funkcji z pakiety `numpy`.
# 2. Użyj odpowiedniej funkcji dopasowania, podając jej: twoją funkcję, dane osi X (`x_data`) i zaszumione dane osi Y (`y_noisy`). Zapisz zwrócone optymalne parametry do krotki (tuple) `(a_opt, b_opt, c_opt)`.
# WSKAZÓWKA: Funkcja zwraca dwie wartości, parametry są w pierwszej z nich.
# 3. Oblicz wygładzone (prawdziwe) wartości, wywołując zdefiniowaną funkcję z optymalnymi parametrami i `x_data`. Wynik przypisz do zmiennej `y_smooth`.
# 4. Stwórz wykres! Na jednym wykresie powinny się znaleźć:
#    * Wykres punktowy (scatter) dla surowych danych (`x_data`, `y_noisy`), kolor zielony ('green') i odpowiednia etykieta (`label`).
#    * Wykres liniowy (plot) dla gładkich danych (`x_data`, `y_smooth`), kolor niebieski ('blue'), pogrubiona linia (`linewidth=5`) i etykieta.
# 5. Dodaj tytuł, opisy obu osi i wyświetl legendę. Na koniec pokaż wykres.

# %%
import numpy as np
np.random.seed(42)
x_data = np.linspace(0.01, 15, 25)
y_noisy=[-29.058849437129 , 0.07322300385301495 , 6.765025802980473 , 11.591310154839816 , 10.064015732778174 , 11.796356850661061 , 17.088144594625078 , 16.720430117611564 , 15.378012683470685 , 18.72176420490221 , 17.825144802377658 , 19.060795886523103 , 21.834620038603195 , 18.662963183477498 , 20.4969128443398 , 24.476650727904556 , 25.18317772243497 , 29.750914727623908 , 29.10629205211394 , 30.123267031357496 , 38.40886183833357 , 37.27647382202343 , 40.501228835142086 , 40.17674832645799 , 45.046384754587336]
#Tu umieść swoje rozwiązanie
